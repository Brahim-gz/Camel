# %%
# !pip install pdfminer.six
# Out:
# ...
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from pdfminer.high_level import extract_text
import pandas as pd
import os
import re

def extract_text_from_pdf(pdf_path):
    try:
        text = extract_text(pdf_path)
        return text
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {e}")
        return None

def preprocess_text(text):
    # Standardize formatting
    text = text.lower()  # Convert to lowercase
    text = ' '.join(text.split())  # Remove extra spaces

    # Handling Special Characters and Punctuation
    text = re.sub(r'[^\w\s]', ' ', text)  # Replace non-word characters with space
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with single space

    return text

# %%
# Specify the directory path
directory = "C:\Users\user\Chatbot\dataset\pflp-documents\eng"

text_data = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    
    # Check if the filepath is a file (not a directory)
    if os.path.isfile(filepath):
        if '.pdf' in filename:
            extracted_text = extract_text_from_pdf(filepath)

# %%
with open(r"C:\Users\user\Downloads\news.ar.en.txt", 'r',encoding='utf-8') as file:
    content = file.read().replace('\n',' ')
    text = preprocess_text(content)

# %%
import os
directory = r"C:\Users\user\dataset\pflp-documents\ar"

new_rows = [] 

for filename in os.listdir(directory):
    filepath = os.path.join(directory, filename)
    new_rows.append([preprocess_text(extract_text_from_pdf(filepath))])

# %%
import csv
with open(r"C:\Users\user\Downloads\dataset_English.csv", 'a', newline='',encoding='utf-8') as csvfile:
    
    csvwriter = csv.writer(csvfile)
    
    for row in new_rows:
        csvwriter.writerow(row)

# %%
# Convert text data to DataFrame
df = pd.DataFrame(text_data)

# Save DataFrame to CSV file
output_file = "dataset.csv"
df.to_csv(output_file, index=False)
